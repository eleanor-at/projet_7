# %%
import cv2
import matplotlib.pyplot as plt

# %%
img_X_1 = cv2.imread("images/image-0097.png")
img_X_2 = cv2.imread("images/image-0098.png")
img_X_3 = cv2.imread("images/image-0099.png")
img_X_1_gris = cv2.cvtColor(img_X_1, cv2.COLOR_BGR2GRAY)[150:200, 1070:1150]
img_X_2_gris = cv2.cvtColor(img_X_2, cv2.COLOR_BGR2GRAY)[150:210, 950:1000]
img_X_3_gris = cv2.cvtColor(img_X_3, cv2.COLOR_BGR2GRAY)[150:210, 1050:1100]

img_XI_1 = cv2.imread("images/image-0106.png")
img_XI_2 = cv2.imread("images/image-0108.png")
img_XI_3 = cv2.imread("images/image-0109.png")
img_XI_1_gris = cv2.cvtColor(img_XI_1, cv2.COLOR_BGR2GRAY)[180:250, 940:1010]
img_XI_2_gris = cv2.cvtColor(img_XI_2, cv2.COLOR_BGR2GRAY)[160:200, 940:1010]
img_XI_3_gris = cv2.cvtColor(img_XI_3, cv2.COLOR_BGR2GRAY)[160:210, 1080:1150]

img_XII_1 = cv2.imread("images/image-0113.png")
img_XII_2 = cv2.imread("images/image-0114.png")
img_XII_3 = cv2.imread("images/image-0115.png")
img_XII_1_gris = cv2.cvtColor(img_XII_1, cv2.COLOR_BGR2GRAY)[160:210, 1050:1130]
img_XII_2_gris = cv2.cvtColor(img_XII_2, cv2.COLOR_BGR2GRAY)[160:210, 930:1000]
img_XII_3_gris = cv2.cvtColor(img_XII_3, cv2.COLOR_BGR2GRAY)[160:210, 1040:1120]

# %%
plt.imshow(img_XII_3_gris[160:210, 1040:1120], cmap = 'gray')
